# %%
print("hi")
# Out:
# hi

# %%
import sys
import traceback
class DocumentPortalException(Exception):
   #"""Custom exception for Document Portal errors."""
    def __init__(self,error_message,error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))
    def __str__(self):
        return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback: {self.traceback_str}
        """
if __name__ == "__main__":
    try:
        a = 1/0
        print(a)
        #raise DocumentPortalException("An error occurred in the Document Portal.")
    except Exception as e:
        app_exc=DocumentPortalException(e,sys)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[43], line 19
#      18 try:
# ---> 19     a = 1/0
#      20     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[43], line 24
#      22 except Exception as e:
#      23     app_exc=DocumentPortalException(e,sys)
# ---> 24     raise app_exc
#
# DocumentPortalException:
#         Error in [/var/folders/t2/q4qry2813v3_bd1zj277c0dm0000gn/T/ipykernel_41910/1028674629.py] at line [19]
#         Message: division by zero
#         Traceback: Traceback (most recent call last):
#   File "/var/folders/t2/q4qry2813v3_bd1zj277c0dm0000gn/T/ipykernel_41910/1028674629.py", line 19, in <module>
#     a = 1/0
# ZeroDivisionError: division by zero

# %%
import importlib
import logger.custom_logger
importlib.reload(logger.custom_logger)
from logger.custom_logger import CustomLogger
logger = CustomLogger().get_logger("exception_experiment")
logger.info("info works")
logger.error("error works")

# %%
import sys
import traceback
class DocumentPortalException(Exception):
   #"""Custom exception for Document Portal errors."""
    def __init__(self,error_message,error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))
    def __str__(self):
        return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback: {self.traceback_str}
        """
if __name__ == "__main__":
    try:
        a = 1/0
        print(a)
        #raise DocumentPortalException("An error occurred in the Document Portal.")
    except Exception as e:
        app_exc=DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[64], line 19
#      18 try:
# ---> 19     a = 1/0
#      20     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[64], line 25
#      23 app_exc=DocumentPortalException(e,sys)
#      24 logger.error(app_exc)
# ---> 25 raise app_exc
#
# DocumentPortalException:
#         Error in [/var/folders/t2/q4qry2813v3_bd1zj277c0dm0000gn/T/ipykernel_41910/3952968528.py] at line [19]
#         Message: division by zero
#         Traceback: Traceback (most recent call last):
#   File "/var/folders/t2/q4qry2813v3_bd1zj277c0dm0000gn/T/ipykernel_41910/3952968528.py", line 19, in <module>
#     a = 1/0
# ZeroDivisionError: division by zero
