# %%
print("hi")
# Out:
# hi

# %%
import sys
import traceback
class DocumentPortalException(Exception):
   #"""Custom exception for Document Portal errors."""
    def __init__(self, error_message,error_details:sys):
        _,_,exec_tb=error_details.exec_info()
        self.file_name=exec_tb.tb_frame.f_code.co_filename
        self.lineno=exec_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exec_info()))
    def __str__(self):
        return f"""
        Error in [{self.file_name}] at line [{self.lineno}]
        Message: {self.error_message}
        Traceback: {self.traceback_str}
        """
if __name__ == "__main__":
    try:
        a = 1/0
        print(a)
        #raise DocumentPortalException("An error occurred in the Document Portal.")
    except Exception as e:
        app_exc=DocumentPortalException(e,sys)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 19
#      18 try:
# ---> 19     a = 1/0
#      20     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 23
#      21     #raise DocumentPortalException("An error occurred in the Document Portal.")
#      22 except Exception as e:
# ---> 23     app_exc=DocumentPortalException(e,sys)
#      24     raise app_exc
#
# Cell In[5], line 6, in DocumentPortalException.__init__(self, error_message, error_details)
#       5 def __init__(self, error_message,error_details:sys):
# ----> 6     _,_,exec_tb=error_details.exec_info()
#       7     self.file_name=exec_tb.tb_frame.f_code.co_filename
#       8     self.lineno=exec_tb.tb_lineno
#
# AttributeError: module 'sys' has no attribute 'exec_info'
