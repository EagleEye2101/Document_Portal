# %%
print("hi")
# Out:
# hi

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir=os.path.join(os.getcwd(), "logs")

# %%
os.makedirs("logs", exist_ok=True)
log_filename = f"logs/log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

# %%
logs_dir
# Out:
# '/Users/kiran_mac/Documents/AI_Training/GenAI_KrishNaik/Document_Portal/notebook/logs'

# %%
log_filename
# Out:
# 'logs/log_20251125_223219.log'

# %%
logging.basicConfig(
    filename=log_filename,
    level=logging.INFO,
    format="[%(asctime)s] %(levelname)s: %(name)s (line:%(lineno)d)- %(message)s",  
)

# %%
logger=logging.getLogger("DocumentPortal").info("This is an info message")

# %%
os.path.join(os.getcwd(),"logs")
# Out:
# '/Users/kiran_mac/Documents/AI_Training/GenAI_KrishNaik/Document_Portal/notebook/logs'

# %%
#jsom format key value pair logging
import structlog
logger=structlog.get_logger()
logger.info("User uploaded a document", user="kiran", document_name="sample.pdf")
# Out:
# 2025-11-25 22:37:47 [info     ] User uploaded a document       document_name=sample.pdf user=kiran
